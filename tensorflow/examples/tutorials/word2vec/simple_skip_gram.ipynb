# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %% [markdown]
# Load the dataset, a period of articles containing 17 million words.

# %%
words[0:15]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including']

# %%
# Step 2-1: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

# %%
# Step 2-2: Build the dictionary and replace rare words with UNK token.
# Without speficied the vocabulary size

def build_dataset_freqcut(words, min_cut_freq):
  count_org = [['UNK', -1]]
  count_org.extend(collections.Counter(words).most_common()) #这里我们收集全部的单词的词频
  count = [['UNK', -1]]
  for word, c in count_org:
    word_tuple = [word, c]
    if word == 'UNK':   #保留UNK的位置已备后用
        count[0][1] = c
        continue
    if c > min_cut_freq: #这里定义一个para为min_cut_freq，少于这个数量的将会被咔掉
        count.append(word_tuple)
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print(len(count))
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# 50000
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# data: the rank of words in terms of frequency in appeared order
#
# count: the K-V pairs of words-appearing times from the most frequent words (besides UNK)
#
# dictionary: K-V pairs of words-rank
#
# reverse_dictionary: K-V pairs of rank-words

# %%
data_index = 0


# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 12 as
# 3084 originated -> 5239 anarchism
# 12 as -> 3084 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# "Anarchism originated as a term of"

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    # tf.nn.embedding_lookup(params, ids, partition_strategy='mod', name=None)
    # embedding_lookup function retrieves ids rows of the params tensor
    # Here we found the embeddings for inputs
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.initialize_all_variables()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 10000 == 0:
      if step > 0:
        average_loss /= 10000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 20000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  271.960968018
# Nearest to these: orcas, fai, minyan, orders, counterweight, voce, vault, kao,
# Nearest to its: midshipman, unranked, fg, encyclopedists, yog, beast, decompression, tamar,
# Nearest to an: tds, mitch, fans, eyed, addressing, hanks, tua, ferret,
# Nearest to some: transactional, footprint, specializing, elsewhere, angli, titans, arius, canto,
# Nearest to such: mohandas, oren, ellefson, enclosing, embarrassment, pathogenic, campaigns, ny,
# Nearest to united: venn, forests, offense, jenny, laude, sharks, suits, compassionate,
# Nearest to i: filippo, mmo, piro, lesley, bewildering, bihar, foundations, commune,
# Nearest to time: thirst, junta, composites, mandragora, vortigern, pushing, relatives, lanthanides,
# Nearest to as: marines, greece, woke, palettes, loach, unofficial, synopsis, moderators,
# Nearest to that: thunderbirds, msg, amato, mourns, porte, carmichael, reconnection, cheers,
# Nearest to their: power, patriot, monterey, hippocampus, ludvig, vn, sheehan, reported,
# Nearest to if: bark, czechoslovakian, bob, bafta, fie, raiders, ligands, kunst,
# Nearest to was: lush, tragedy, yupik, posted, hertz, once, vantaa, medline,
# Nearest to five: docile, declassified, ttingen, kos, neman, berlin, bfi, trajectories,
# Nearest to most: paddle, giordano, battleground, oliphant, property, gripped, folklore, photograph,
# Nearest to up: huckleberry, caught, plutonic, overture, duodecimal, lama, misc, angers,
# Average loss at step  10000 :  48.3890299869
# Average loss at step  20000 :  10.3133885133
# Nearest to these: bonds, orders, which, the, that, agouti, those, abet,
# Nearest to its: the, his, dasyprocta, a, their, atm, noticeable, critique,
# Nearest to an: dasyprocta, hanks, the, stout, recreational, this, phi, fatherland,
# Nearest to some: the, this, chaldean, agouti, phi, surprised, rosamund, a,
# Nearest to such: known, intentional, phi, mohandas, huston, circular, well, critically,
# Nearest to united: venn, problem, professor, agouti, phi, jenny, on, offense,
# Nearest to i: filippo, dasyprocta, greene, foundations, encoding, they, UNK, commune,
# Nearest to time: relatives, beginning, thirst, vortigern, mathbf, agouti, coke, liquid,
# Nearest to as: by, dasyprocta, mathbf, phi, is, and, for, antwerp,
# Nearest to that: msg, dasyprocta, auschwitz, which, lossless, contarini, and, mil,
# Nearest to their: the, patriot, monterey, his, rotated, its, power, ridges,
# Nearest to if: bark, peruvian, bob, phi, agouti, herder, operatorname, combined,
# Nearest to was: is, by, were, are, had, antwerp, dasyprocta, as,
# Nearest to five: six, zero, nine, eight, seven, four, two, three,
# Nearest to most: folklore, paddle, leap, photograph, antwerp, flooding, use, dasyprocta,
# Nearest to up: caught, aa, psychiatrist, holiday, dasyprocta, isaiah, coke, angels,
# Average loss at step  30000 :  6.64945658736
# Average loss at step  40000 :  5.60176596193
# Nearest to these: orders, which, those, bonds, the, UNK, hyphen, amalthea,
# Nearest to its: the, their, his, dasyprocta, UNK, atm, noticeable, a,
# Nearest to an: hanks, the, dasyprocta, tua, tds, phi, rigidity, recreational,
# Nearest to some: many, the, this, agouti, all, chaldean, phi, other,
# Nearest to such: known, well, reuptake, callisto, artistic, huston, phi, other,
# Nearest to united: on, jenny, venn, problem, nuke, agouti, professor, morris,
# Nearest to i: they, UNK, dasyprocta, encoding, filippo, foundations, ambush, reuptake,
# Nearest to time: beginning, relatives, thirst, reuptake, vortigern, mathbf, pushing, coke,
# Nearest to as: dasyprocta, mathbf, phi, by, in, operatorname, and, antwerp,
# Nearest to that: which, amalthea, but, msg, this, dasyprocta, auschwitz, recitative,
# Nearest to their: its, the, his, monterey, amalthea, a, patriot, power,
# Nearest to if: bark, peruvian, is, bob, herder, phi, but, agouti,
# Nearest to was: is, were, had, by, has, abitibi, became, UNK,
# Nearest to five: four, six, three, eight, seven, two, zero, nine,
# Nearest to most: folklore, use, paddle, prism, leap, colder, abet, last,
# Nearest to up: caught, them, circulated, stwa, psychiatrist, operatorname, aalto, overture,
# Average loss at step  50000 :  5.24673853753
# Average loss at step  60000 :  5.02389520588
# Nearest to these: some, which, orders, those, many, several, all, varies,
# Nearest to its: their, his, the, microcebus, callithrix, dasyprocta, goodies, upanija,
# Nearest to an: hanks, the, recreational, tds, tua, rigidity, dasyprocta, ministry,
# Nearest to some: many, the, ssbn, all, these, this, microcebus, other,
# Nearest to such: known, well, cobbler, many, reuptake, some, rheumatoid, other,
# Nearest to united: balboa, callithrix, on, thibetanus, tabor, nuke, agouti, jenny,
# Nearest to i: encoding, dasyprocta, they, tamarin, UNK, ii, ambush, reuptake,
# Nearest to time: cardiomyopathy, reuptake, beginning, callithrix, marmoset, vortigern, cobbler, thirst,
# Nearest to as: tamarin, dasyprocta, mathbf, callithrix, microcebus, phi, operatorname, ssbn,
# Nearest to that: which, this, amalthea, tamarin, but, recitative, dasyprocta, when,
# Nearest to their: its, his, the, monterey, microcebus, her, some, upanija,
# Nearest to if: microcebus, peruvian, saguinus, marmoset, tamarin, but, when, bark,
# Nearest to was: is, were, had, has, by, became, abitibi, tamarin,
# Nearest to five: four, six, eight, three, seven, nine, zero, two,
# Nearest to most: folklore, more, use, prism, callithrix, cebus, wct, colder,
# Nearest to up: caught, them, stwa, circulated, operatorname, microsite, correctly, spores,
# Average loss at step  70000 :  4.88437726048
# Average loss at step  80000 :  4.84886424922
# Nearest to these: some, many, several, those, which, such, orders, all,
# Nearest to its: their, his, the, microcebus, her, callithrix, upanija, goodies,
# Nearest to an: tua, hanks, tds, inoculation, recreational, masai, rigidity, jag,
# Nearest to some: many, these, all, several, ssbn, any, other, this,
# Nearest to such: known, well, these, some, many, cobbler, including, reuptake,
# Nearest to united: balboa, tabor, on, nuke, callithrix, thibetanus, jenny, agouti,
# Nearest to i: they, ii, UNK, encoding, dasyprocta, tamarin, ambush, nbs,
# Nearest to time: reuptake, cardiomyopathy, beginning, vortigern, marmoset, callithrix, tabletop, catalysis,
# Nearest to as: tamarin, dasyprocta, callithrix, phi, microcebus, cegep, by, operatorname,
# Nearest to that: which, tamarin, this, amalthea, dasyprocta, but, recitative, microcebus,
# Nearest to their: its, his, the, her, microcebus, upanija, abitibi, monterey,
# Nearest to if: when, peruvian, microcebus, tamarin, saguinus, marmoset, is, but,
# Nearest to was: is, had, were, became, has, abitibi, tamarin, by,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to most: more, folklore, some, prism, use, many, callithrix, wct,
# Nearest to up: them, caught, out, stwa, chopsticks, operatorname, correctly, microsite,
# Average loss at step  90000 :  4.76252940248
# Average loss at step  100000 :  4.69429102757
# Nearest to these: some, many, several, all, those, such, which, are,
# Nearest to its: their, his, the, our, her, microcebus, eurocents, callithrix,
# Nearest to an: tua, tds, hanks, masai, inoculation, rigidity, prescott, recreational,
# Nearest to some: many, these, all, several, any, ssbn, other, the,
# Nearest to such: known, well, these, many, some, including, abbreviated, reuptake,
# Nearest to united: balboa, tabor, nuke, bunyip, callithrix, beaked, jenny, dormitory,
# Nearest to i: they, encoding, ii, dasyprocta, tamarin, we, ambush, he,
# Nearest to time: reuptake, mesoplodon, callithrix, marmoset, way, beginning, cardiomyopathy, vortigern,
# Nearest to as: tamarin, dasyprocta, callithrix, microcebus, when, in, cegep, ssbn,
# Nearest to that: which, however, amalthea, this, tamarin, auschwitz, but, recitative,
# Nearest to their: its, his, the, her, our, some, microcebus, amalthea,
# Nearest to if: when, is, microcebus, tamarin, marmoset, peruvian, because, callithrix,
# Nearest to was: is, had, has, were, became, abitibi, when, by,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to most: more, many, folklore, some, use, prism, callithrix, colder,
# Nearest to up: them, caught, out, stwa, back, chopsticks, correctly, bout,

# %%
# %matplotlib inline

# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
